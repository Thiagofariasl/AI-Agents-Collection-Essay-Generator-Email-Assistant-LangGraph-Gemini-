# %%
# %pip install python-dotenv
# %pip install -U langgraph langchain langchain-google-genai langchain-tavily python-dotenv aiosqlite
# Out:
# Requirement already satisfied: python-dotenv in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Thiago\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: langgraph in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.1.5)
# Collecting langgraph
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: langchain in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.15)
# Requirement already satisfied: langchain-google-genai in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.2.1)
# Requirement already satisfied: langchain-tavily in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.17)
# Requirement already satisfied: python-dotenv in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.2)
# Collecting aiosqlite
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (1.2.23)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (0.3.12)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai) (1.70.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-tavily) (3.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-tavily) (2.33.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.23.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.49.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (0.7.23)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (0.14.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.8)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2026.2.25)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.6)
# Requirement already satisfied: httpcore==1.* in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.0)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
#    ---------------------------------------- 0.0/169.8 kB ? eta -:--:--
#    ---------------------------------------- 169.8/169.8 kB 5.0 MB/s eta 0:00:00
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Installing collected packages: aiosqlite, langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.1.5
#     Uninstalling langgraph-1.1.5:
#       Successfully uninstalled langgraph-1.1.5
# Successfully installed aiosqlite-0.22.1 langgraph-1.1.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Thiago\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GEMINI_API_KEY') 
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

# %%
# %pip install --upgrade langgraph
# %pip install langgraph-checkpoint-sqlite
# Out:
# Requirement already satisfied: langgraph in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.1.6)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (1.2.23)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (0.3.12)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (0.7.23)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.1->langgraph) (0.14.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.8)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: anyio in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.13.0)
# Requirement already satisfied: certifi in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Thiago\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting langgraph-checkpoint-sqlite
#   Downloading langgraph_checkpoint_sqlite-3.0.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: aiosqlite>=0.20 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint-sqlite) (0.22.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=3 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint-sqlite) (4.0.1)
# Collecting sqlite-vec>=0.1.6 (from langgraph-checkpoint-sqlite)
#   Downloading sqlite_vec-0.1.9-py3-none-win_amd64.whl.metadata (198 bytes)
# Requirement already satisfied: langchain-core>=0.2.38 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (1.2.23)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (1.12.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.7.23)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.4.2)
# Requirement already satisfied: anyio in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (4.13.0)
# Requirement already satisfied: certifi in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (1.0.9)
# Requirement already satisfied: idna in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\thiago\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=3->langgraph-checkpoint-sqlite) (2.6.3)
# Downloading langgraph_checkpoint_sqlite-3.0.3-py3-none-any.whl (33 kB)
# Downloading sqlite_vec-0.1.9-py3-none-win_amd64.whl (292 kB)
#    ---------------------------------------- 0.0/292.8 kB ? eta -:--:--
#    ---------------------------------------  286.7/292.8 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 292.8/292.8 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: sqlite-vec, langgraph-checkpoint-sqlite
# Successfully installed langgraph-checkpoint-sqlite-3.0.3 sqlite-vec-0.1.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Thiago\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import operator
from typing import Annotated, List, Any, Dict
from dataclasses import dataclass, field
from langgraph.graph import StateGraph, END
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage, BaseMessage, AnyMessage

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilySearch

from langgraph.checkpoint.sqlite import SqliteSaver

from typing_extensions import TypedDict

import sqlite3

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        
        graph = StateGraph(AgentState)

        graph.add_node("llm", self.call_gemini)

        graph.add_node("action", self.take_action)

        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})

        graph.add_edge("action", "llm")

        graph.set_entry_point("llm")

        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_gemini(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages

        print("Mensagens enviadas ao modelo:", messages)
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling Tool: {t['name']} with args: {t['args']}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Returning to LLM after action!")
        return {'messages': results}

# %%
current_tavily_api_key = os.getenv('TAVILY_API_KEY')
if not current_tavily_api_key:
    raise ValueError("TAVILY_API_KEY não encontrada. Certifique-se de que está no seu .env e python-dotenv está instalado.")

tool = TavilySearch(max_results=3, tavily_api_key=current_tavily_api_key)


prompt_system = """Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.
Você tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).
Busque informações apenas quando tiver certeza do que procurar.
Se precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.
Quando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas."""

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite") 

abot = Agent(model, [tool], system=prompt_system, checkpointer=memory)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
messages = [HumanMessage(content="Como está o tempo em São Paulo hoje (07/04/2026)?")]
thread = {"configurable": {"thread_id": "1"}} 


print("\n--- Pergunta 1: Tempo em São Paulo ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"): 
             print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 1: Tempo em São Paulo ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={})]
# llm: [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "previs\\u00e3o do tempo S\\u00e3o Paulo 07/04/2026"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-b46b-72e0-847b-3849f96a5aa1-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}, 'id': '6a87adfd-d509-436c-a760-963bebe58a6e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1594, 'output_tokens': 41, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}})]
# Calling Tool: tavily_search with args: {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}
# Returning to LLM after action!
# action: [ToolMessage(content="{'query': 'previsão do tempo São Paulo 07/04/2026', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.instagram.com/p/DW1BbeiDZZH/', 'title': 'Previsão do Tempo 07/04/2026 - Instagram', 'content': 'SÃO PAULO PREVISÃO DO TEMPO SEMANAL (Seg) 16/03 (Ter) 17/03 (Qua) 18/03 (Qui) 19/03 (Sex) 20/03 (Sab) (Sab)21/03 21/03 18°CMIM 18 MIM 31 31CMAX MAX (Dom)', 'score': 0.9999497, 'raw_content': None}, {'url': 'https://gcmais.com.br/noticias/2026/04/06/clima-para-amanha-em-sao-paulo-previsao-do-tempo-para-terca-07-04/', 'title': 'Clima para amanhã em São Paulo: previsão do tempo para terça ...', 'content': 'Manhã (6h-12h): Nuvens dispersas, temperatura de 18°C a 25°C. · Tarde (12h-18h): Parcialmente nublado com risco de garoa, pico de 29°C e UV alto (FPS 15-25).', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://www.agenciasp.sp.gov.br/previsao-do-tempo-para-terca-feira-07-em-sp-sol-entre-algumas-nuvens/', 'title': 'Previsão do tempo para terça-feira (07) em SP: sol entre algumas ...', 'content': 'Agência de Notícias do Governo do Estado de São Paulo. # Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. Nesta terça-feira, o dia será marcado por sol entre algumas nuvens no estado de São Paulo. Pela manhã, o tempo segue estável, com temperaturas em gradativa elevação e sensação de abafamento persistente. No período da tarde, o calor e a alta umidade formam áreas de instabilidade, que causam pancadas de chuva isoladas, com intensidade variando entre fraca a moderada no território paulista. Em dias quentes, consulte a previsão do tempo e beba bastante água para se proteger da secura. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. ### Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. ### Governo de SP amplia cooperação com municípios em congresso com foco em gestão, inovação e políticas públicas. ### Governo de SP leva Poupatempo Móvel a Leme e Sete Barras nesta semana.', 'score': 0.99722075, 'raw_content': None}], 'response_time': 1.12, 'request_id': 'aa6f7209-003e-4a7e-8d99-ab15d9e1a6a7'}", name='tavily_search', tool_call_id='6a87adfd-d509-436c-a760-963bebe58a6e')]
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "previs\\u00e3o do tempo S\\u00e3o Paulo 07/04/2026"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-b46b-72e0-847b-3849f96a5aa1-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}, 'id': '6a87adfd-d509-436c-a760-963bebe58a6e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1594, 'output_tokens': 41, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'previsão do tempo São Paulo 07/04/2026', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.instagram.com/p/DW1BbeiDZZH/', 'title': 'Previsão do Tempo 07/04/2026 - Instagram', 'content': 'SÃO PAULO PREVISÃO DO TEMPO SEMANAL (Seg) 16/03 (Ter) 17/03 (Qua) 18/03 (Qui) 19/03 (Sex) 20/03 (Sab) (Sab)21/03 21/03 18°CMIM 18 MIM 31 31CMAX MAX (Dom)', 'score': 0.9999497, 'raw_content': None}, {'url': 'https://gcmais.com.br/noticias/2026/04/06/clima-para-amanha-em-sao-paulo-previsao-do-tempo-para-terca-07-04/', 'title': 'Clima para amanhã em São Paulo: previsão do tempo para terça ...', 'content': 'Manhã (6h-12h): Nuvens dispersas, temperatura de 18°C a 25°C. · Tarde (12h-18h): Parcialmente nublado com risco de garoa, pico de 29°C e UV alto (FPS 15-25).', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://www.agenciasp.sp.gov.br/previsao-do-tempo-para-terca-feira-07-em-sp-sol-entre-algumas-nuvens/', 'title': 'Previsão do tempo para terça-feira (07) em SP: sol entre algumas ...', 'content': 'Agência de Notícias do Governo do Estado de São Paulo. # Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. Nesta terça-feira, o dia será marcado por sol entre algumas nuvens no estado de São Paulo. Pela manhã, o tempo segue estável, com temperaturas em gradativa elevação e sensação de abafamento persistente. No período da tarde, o calor e a alta umidade formam áreas de instabilidade, que causam pancadas de chuva isoladas, com intensidade variando entre fraca a moderada no território paulista. Em dias quentes, consulte a previsão do tempo e beba bastante água para se proteger da secura. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. ### Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. ### Governo de SP amplia cooperação com municípios em congresso com foco em gestão, inovação e políticas públicas. ### Governo de SP leva Poupatempo Móvel a Leme e Sete Barras nesta semana.', 'score': 0.99722075, 'raw_content': None}], 'response_time': 1.12, 'request_id': 'aa6f7209-003e-4a7e-8d99-ab15d9e1a6a7'}", name='tavily_search', tool_call_id='6a87adfd-d509-436c-a760-963bebe58a6e')]
# llm: [AIMessage(content='Em São Paulo, em 7 de abril de 2026, a previsão do tempo indica um dia com sol entre algumas nuvens. Pela manhã, o tempo estará estável, com temperaturas subindo gradualmente e sensação de abafamento. À tarde, o calor e a alta umidade podem gerar pancadas de chuva isoladas, com intensidade de fraca a moderada. As temperaturas devem variar entre 18°C e 29°C.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-c025-7723-9afe-b32d7da40231-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2481, 'output_tokens': 98, 'total_tokens': 2579, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="E no Rio de Janeiro?")]
thread = {"configurable": {"thread_id": "1"}} 

print("\n--- Pergunta 2: Tempo no Rio de Janeiro ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 2: Tempo no Rio de Janeiro ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "previs\\u00e3o do tempo S\\u00e3o Paulo 07/04/2026"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-b46b-72e0-847b-3849f96a5aa1-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}, 'id': '6a87adfd-d509-436c-a760-963bebe58a6e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1594, 'output_tokens': 41, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'previsão do tempo São Paulo 07/04/2026', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.instagram.com/p/DW1BbeiDZZH/', 'title': 'Previsão do Tempo 07/04/2026 - Instagram', 'content': 'SÃO PAULO PREVISÃO DO TEMPO SEMANAL (Seg) 16/03 (Ter) 17/03 (Qua) 18/03 (Qui) 19/03 (Sex) 20/03 (Sab) (Sab)21/03 21/03 18°CMIM 18 MIM 31 31CMAX MAX (Dom)', 'score': 0.9999497, 'raw_content': None}, {'url': 'https://gcmais.com.br/noticias/2026/04/06/clima-para-amanha-em-sao-paulo-previsao-do-tempo-para-terca-07-04/', 'title': 'Clima para amanhã em São Paulo: previsão do tempo para terça ...', 'content': 'Manhã (6h-12h): Nuvens dispersas, temperatura de 18°C a 25°C. · Tarde (12h-18h): Parcialmente nublado com risco de garoa, pico de 29°C e UV alto (FPS 15-25).', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://www.agenciasp.sp.gov.br/previsao-do-tempo-para-terca-feira-07-em-sp-sol-entre-algumas-nuvens/', 'title': 'Previsão do tempo para terça-feira (07) em SP: sol entre algumas ...', 'content': 'Agência de Notícias do Governo do Estado de São Paulo. # Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. Nesta terça-feira, o dia será marcado por sol entre algumas nuvens no estado de São Paulo. Pela manhã, o tempo segue estável, com temperaturas em gradativa elevação e sensação de abafamento persistente. No período da tarde, o calor e a alta umidade formam áreas de instabilidade, que causam pancadas de chuva isoladas, com intensidade variando entre fraca a moderada no território paulista. Em dias quentes, consulte a previsão do tempo e beba bastante água para se proteger da secura. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. ### Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. ### Governo de SP amplia cooperação com municípios em congresso com foco em gestão, inovação e políticas públicas. ### Governo de SP leva Poupatempo Móvel a Leme e Sete Barras nesta semana.', 'score': 0.99722075, 'raw_content': None}], 'response_time': 1.12, 'request_id': 'aa6f7209-003e-4a7e-8d99-ab15d9e1a6a7'}", name='tavily_search', tool_call_id='6a87adfd-d509-436c-a760-963bebe58a6e'), AIMessage(content='Em São Paulo, em 7 de abril de 2026, a ...
# llm: [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "previs\\u00e3o do tempo Rio de Janeiro 07/04/2026", "time_range": "day"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a09-1622-7a42-8ede-bf41540e5989-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'previsão do tempo Rio de Janeiro 07/04/2026', 'time_range': 'day'}, 'id': '69f26061-cde7-4557-8940-aaf33609ee2d', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2587, 'output_tokens': 42, 'total_tokens': 2629, 'input_token_details': {'cache_read': 0}})]
# Calling Tool: tavily_search with args: {'query': 'previsão do tempo Rio de Janeiro 07/04/2026', 'time_range': 'day'}
# Returning to LLM after action!
# action: [ToolMessage(content="No search results found for 'previsão do tempo Rio de Janeiro 07/04/2026'. Suggestions: Remove time_range argument, Try a more detailed search using 'advanced' search_depth. Try modifying your search parameters with one of these approaches.", name='tavily_search', tool_call_id='69f26061-cde7-4557-8940-aaf33609ee2d')]
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "previs\\u00e3o do tempo S\\u00e3o Paulo 07/04/2026"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-b46b-72e0-847b-3849f96a5aa1-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}, 'id': '6a87adfd-d509-436c-a760-963bebe58a6e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1594, 'output_tokens': 41, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'previsão do tempo São Paulo 07/04/2026', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.instagram.com/p/DW1BbeiDZZH/', 'title': 'Previsão do Tempo 07/04/2026 - Instagram', 'content': 'SÃO PAULO PREVISÃO DO TEMPO SEMANAL (Seg) 16/03 (Ter) 17/03 (Qua) 18/03 (Qui) 19/03 (Sex) 20/03 (Sab) (Sab)21/03 21/03 18°CMIM 18 MIM 31 31CMAX MAX (Dom)', 'score': 0.9999497, 'raw_content': None}, {'url': 'https://gcmais.com.br/noticias/2026/04/06/clima-para-amanha-em-sao-paulo-previsao-do-tempo-para-terca-07-04/', 'title': 'Clima para amanhã em São Paulo: previsão do tempo para terça ...', 'content': 'Manhã (6h-12h): Nuvens dispersas, temperatura de 18°C a 25°C. · Tarde (12h-18h): Parcialmente nublado com risco de garoa, pico de 29°C e UV alto (FPS 15-25).', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://www.agenciasp.sp.gov.br/previsao-do-tempo-para-terca-feira-07-em-sp-sol-entre-algumas-nuvens/', 'title': 'Previsão do tempo para terça-feira (07) em SP: sol entre algumas ...', 'content': 'Agência de Notícias do Governo do Estado de São Paulo. # Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. Nesta terça-feira, o dia será marcado por sol entre algumas nuvens no estado de São Paulo. Pela manhã, o tempo segue estável, com temperaturas em gradativa elevação e sensação de abafamento persistente. No período da tarde, o calor e a alta umidade formam áreas de instabilidade, que causam pancadas de chuva isoladas, com intensidade variando entre fraca a moderada no território paulista. Em dias quentes, consulte a previsão do tempo e beba bastante água para se proteger da secura. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. ### Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. ### Governo de SP amplia cooperação com municípios em congresso com foco em gestão, inovação e políticas públicas. ### Governo de SP leva Poupatempo Móvel a Leme e Sete Barras nesta semana.', 'score': 0.99722075, 'raw_content': None}], 'response_time': 1.12, 'request_id': 'aa6f7209-003e-4a7e-8d99-ab15d9e1a6a7'}", name='tavily_search', tool_call_id='6a87adfd-d509-436c-a760-963bebe58a6e'), AIMessage(content='Em São Paulo, em 7 de abril de 2026, a ...
# llm: [AIMessage(content='Não encontrei informações específicas sobre a previsão do tempo para o Rio de Janeiro em 07/04/2026.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a09-2451-7101-abfb-095f04eef6a0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2704, 'output_tokens': 28, 'total_tokens': 2732, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Qual está mais quente?")]
thread = {"configurable": {"thread_id": "1"}} 

print("\n--- Pergunta 3: Comparação ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 3: Comparação ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Como está o tempo em São Paulo hoje (07/04/2026)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"time_range": "day", "query": "previs\\u00e3o do tempo S\\u00e3o Paulo 07/04/2026"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a05-b46b-72e0-847b-3849f96a5aa1-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'previsão do tempo São Paulo 07/04/2026'}, 'id': '6a87adfd-d509-436c-a760-963bebe58a6e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1594, 'output_tokens': 41, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'previsão do tempo São Paulo 07/04/2026', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.instagram.com/p/DW1BbeiDZZH/', 'title': 'Previsão do Tempo 07/04/2026 - Instagram', 'content': 'SÃO PAULO PREVISÃO DO TEMPO SEMANAL (Seg) 16/03 (Ter) 17/03 (Qua) 18/03 (Qui) 19/03 (Sex) 20/03 (Sab) (Sab)21/03 21/03 18°CMIM 18 MIM 31 31CMAX MAX (Dom)', 'score': 0.9999497, 'raw_content': None}, {'url': 'https://gcmais.com.br/noticias/2026/04/06/clima-para-amanha-em-sao-paulo-previsao-do-tempo-para-terca-07-04/', 'title': 'Clima para amanhã em São Paulo: previsão do tempo para terça ...', 'content': 'Manhã (6h-12h): Nuvens dispersas, temperatura de 18°C a 25°C. · Tarde (12h-18h): Parcialmente nublado com risco de garoa, pico de 29°C e UV alto (FPS 15-25).', 'score': 0.9999292, 'raw_content': None}, {'url': 'https://www.agenciasp.sp.gov.br/previsao-do-tempo-para-terca-feira-07-em-sp-sol-entre-algumas-nuvens/', 'title': 'Previsão do tempo para terça-feira (07) em SP: sol entre algumas ...', 'content': 'Agência de Notícias do Governo do Estado de São Paulo. # Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. Nesta terça-feira, o dia será marcado por sol entre algumas nuvens no estado de São Paulo. Pela manhã, o tempo segue estável, com temperaturas em gradativa elevação e sensação de abafamento persistente. No período da tarde, o calor e a alta umidade formam áreas de instabilidade, que causam pancadas de chuva isoladas, com intensidade variando entre fraca a moderada no território paulista. Em dias quentes, consulte a previsão do tempo e beba bastante água para se proteger da secura. Geração de empregos e alta na atividade econômica explicam redução da pobreza em SP. ### Previsão do tempo para terça-feira (07) em SP: sol entre algumas nuvens. ### Governo de SP amplia cooperação com municípios em congresso com foco em gestão, inovação e políticas públicas. ### Governo de SP leva Poupatempo Móvel a Leme e Sete Barras nesta semana.', 'score': 0.99722075, 'raw_content': None}], 'response_time': 1.12, 'request_id': 'aa6f7209-003e-4a7e-8d99-ab15d9e1a6a7'}", name='tavily_search', tool_call_id='6a87adfd-d509-436c-a760-963bebe58a6e'), AIMessage(content='Em São Paulo, em 7 de abril de 2026, a ...
# llm: [AIMessage(content='Não tenho informações sobre o tempo no Rio de Janeiro para poder comparar.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6a09-cf00-7a63-b60b-35aca9d5cd89-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2739, 'output_tokens': 14, 'total_tokens': 2753, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Qual está mais quente?")]
thread = {"configurable": {"thread_id": "2"}} 

print("\n--- Pergunta 4: Comparação ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 4: Comparação ---
# Mensagens enviadas ao modelo: [SystemMessage(content='Você é um assistente de pesquisa inteligente. Use o mecanismo de busca (tavily_search_results_json) para procurar informações.\nVocê tem permissão para fazer múltiplas chamadas à ferramenta (em conjunto ou em sequência).\nBusque informações apenas quando tiver certeza do que procurar.\nSe precisar de mais detalhes para formular uma pergunta de acompanhamento, você tem permissão para fazer isso.\nQuando solicitado a comparar informações (ex: qual é mais quente, maior, etc.), use as informações do histórico da conversa e dos resultados das ferramentas.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--a8133944-57a7-4ad9-9fc0-cd36d1a61a45-0', usage_metadata={'input_tokens': 1208, 'output_tokens': 23, 'total_tokens': 1231, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--00d82cce-7911-4134-841a-b311997fe866-0', usage_metadata={'input_tokens': 1236, 'output_tokens': 24, 'total_tokens': 1260, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--4b0fd3d1-0a78-4646-95df-1cd94302ea17-0', usage_metadata={'input_tokens': 1264, 'output_tokens': 24, 'total_tokens': 1288, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--9b02ee4f-9ea4-4135-b4f0-ec9ad4fbf85c-0', usage_metadata={'input_tokens': 1292, 'output_tokens': 24, 'total_tokens': 1316, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--cbebb9e5-468b-4a3d-b93c-012e2cffccc9-0', usage_metadata={'input_tokens': 1320, 'output_tokens': 24, 'total_tokens': 1344, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Qual está mais quente?', additional_kwargs={}, response_metadata={}), AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--c1dda1f6-c290-4923-8192-766db87533c6-0', usage_metadata={' ...
# llm: [AIMessage(content='Mais quente do que o quê? Por favor, forneça o contexto para que eu possa responder à sua pergunta.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run--09fe973d-0d81-4d11-a5ea-7ae528929c6d-0', usage_metadata={'input_tokens': 5752, 'output_tokens': 24, 'total_tokens': 5776, 'input_token_details': {'cache_read': 0}})]
